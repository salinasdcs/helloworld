# %%
import os
import pandas as pd
import numpy as np
import random

# %%
csvFilePath = os.path.join(os.getcwd(), 'roster.csv')

# %% [markdown]
# ### Read CSV to DataFrame

# %%
roster = pd.read_csv(csvFilePath)
print(type(roster))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# #### Viewing the data

# %%
roster.head()
# Out:
#         name
# 0        Joe
# 1     Jihuan
# 2        Ali
# 3    Frances
# 4  Daniela V

# %%
roster.tail()
# Out:
#         name
# 17  Hsin-Yun
# 18    Renata
# 19       Max
# 20    Joshua
# 21     David

# %%
roster
# Out:
#          name
# 0         Joe
# 1      Jihuan
# 2         Ali
# 3     Frances
# 4   Daniela V
# 5     Mostafa
# 6   Daniela P
# 7       Cesar
# 8      Jarrod
# 9      Austin
# 10       Jack
# 11        Ala
# 12     Sergii
# 13      Miles
# 14     Hyeyun
# 15  Volodymyr
# 16      Yijia
# 17   Hsin-Yun
# 18     Renata
# 19        Max
# 20     Joshua
# 21      David

# %% [markdown]
# ### Modifying the Data

# %%
d = {'name': ['Wally']}
tmp_df =pd.DataFrame(data = d)
roster = pd.concat([roster, tmp_df], ignore_index = True)

# %%
roster.tail()
# Out:
#       name
# 18  Renata
# 19     Max
# 20  Joshua
# 21   David
# 22   Wally

# %% [markdown]
# #### Assign Grades

# %%
np.random.seed(1)
roster['grade'] = np.random.randint(0, 100, size = len(roster))
roster
# Out:
#          name  grade
# 0         Joe     37
# 1      Jihuan     12
# 2         Ali     72
# 3     Frances      9
# 4   Daniela V     75
# 5     Mostafa      5
# 6   Daniela P     79
# 7       Cesar     64
# 8      Jarrod     16
# 9      Austin      1
# 10       Jack     76
# 11        Ala     71
# 12     Sergii      6
# 13      Miles     25
# 14     Hyeyun     50
# 15  Volodymyr     20
# 16      Yijia     18
# 17   Hsin-Yun     84
# 18     Renata     11
# 19        Max     28
# 20     Joshua     29
# 21      David     14
# 22      Wally     50

# %% [markdown]
# .loc can be used with a boolean array (i.e. of 1s and 0s)

# %%
roster['name'] == "Daniela P"
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6      True
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# Name: name, dtype: bool

# %%
roster.loc[roster['name'] == "Daniela P", 'grade'] = 100
roster
# Out:
#          name  grade
# 0         Joe     37
# 1      Jihuan     12
# 2         Ali     72
# 3     Frances      9
# 4   Daniela V     75
# 5     Mostafa      5
# 6   Daniela P    100
# 7       Cesar     64
# 8      Jarrod     16
# 9      Austin      1
# 10       Jack     76
# 11        Ala     71
# 12     Sergii      6
# 13      Miles     25
# 14     Hyeyun     50
# 15  Volodymyr     20
# 16      Yijia     18
# 17   Hsin-Yun     84
# 18     Renata     11
# 19        Max     28
# 20     Joshua     29
# 21      David     14
# 22      Wally     50

# %% [markdown]
# ### Check the class average
#
# Each colum pandas dataframe is a series object -- which have dozens of built-in methods

# %%
roster['grade'].mean()
# Out:
# 37.95652173913044

# %%
roster.loc[roster['grade'] < 50, 'grade'] = roster['grade'] + 40
roster
# Out:
#          name  grade
# 0         Joe     77
# 1      Jihuan     52
# 2         Ali     72
# 3     Frances     49
# 4   Daniela V     75
# 5     Mostafa     45
# 6   Daniela P    100
# 7       Cesar     64
# 8      Jarrod     56
# 9      Austin     41
# 10       Jack     76
# 11        Ala     71
# 12     Sergii     46
# 13      Miles     65
# 14     Hyeyun     50
# 15  Volodymyr     60
# 16      Yijia     58
# 17   Hsin-Yun     84
# 18     Renata     51
# 19        Max     68
# 20     Joshua     69
# 21      David     54
# 22      Wally     50

# %%
roster['grade'].mean()
# Out:
# 62.30434782608695

# %%
roster.loc[roster['grade'] < 60, 'grade'] = roster['grade'] + 30
roster['grade'].mean()
# Out:
# 76.65217391304348

# %% [markdown]
# ### Write to CSV

# %%
outFilePath = os.path.join(os.getcwd(), 'roster_pandas.csv')
print(outFilePath)
# Out:
# /Users/salinasc/helloworld/roster_pandas.csv

# %%
roster.to_csv(outFilePath, index = False) # Don't create a column for index

# %% [markdown]
# ### More Aggregation and Manipulation

# %%
np.random.choice(['red', 'blue'], size = len(roster))
# Out:
# array(['red', 'blue', 'blue', 'blue', 'blue', 'blue', 'red', 'red', 'red',
#        'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'red', 'blue',
#        'blue', 'red', 'red', 'blue', 'red', 'red'], dtype='<U4')

# %%
np.random.seed(2)
roster['group'] = np.random.choice(['red', 'blue'], size = len(roster))
roster
# Out:
#          name  grade group
# 0         Joe     77   red
# 1      Jihuan     82  blue
# 2         Ali     72  blue
# 3     Frances     79   red
# 4   Daniela V     75   red
# 5     Mostafa     75  blue
# 6   Daniela P    100   red
# 7       Cesar     64  blue
# 8      Jarrod     86   red
# 9      Austin     71  blue
# 10       Jack     76   red
# 11        Ala     71  blue
# 12     Sergii     76  blue
# 13      Miles     65  blue
# 14     Hyeyun     80  blue
# 15  Volodymyr     60  blue
# 16      Yijia     88  blue
# 17   Hsin-Yun     84  blue
# 18     Renata     81   red
# 19        Max     68   red
# 20     Joshua     69   red
# 21      David     84   red
# 22      Wally     80  blue

# %%
group_means =  roster.groupby(by = ['group']).mean()
group_means
# Out:
#            grade
# group
# blue   74.461538
# red    79.500000

# %%
group_means.rename(columns = {'grade': 'group_avg'}, inplace = True)
group_means
# Out:
#        group_avg
# group
# blue   74.461538
# red    79.500000

# %% [markdown]
# ### Merging DataFrames

# %%
print(roster.shape)
print(group_means.shape)
# Out:
# (23, 3)
# (2, 1)

# %%
roster = roster.merge(group_means, on = ['group'])
roster
# Out:
#          name  grade group  group_avg
# 0         Joe     77   red  79.500000
# 1     Frances     79   red  79.500000
# 2   Daniela V     75   red  79.500000
# 3   Daniela P    100   red  79.500000
# 4      Jarrod     86   red  79.500000
# 5        Jack     76   red  79.500000
# 6      Renata     81   red  79.500000
# 7         Max     68   red  79.500000
# 8      Joshua     69   red  79.500000
# 9       David     84   red  79.500000
# 10     Jihuan     82  blue  74.461538
# 11        Ali     72  blue  74.461538
# 12    Mostafa     75  blue  74.461538
# 13      Cesar     64  blue  74.461538
# 14     Austin     71  blue  74.461538
# 15        Ala     71  blue  74.461538
# 16     Sergii     76  blue  74.461538
# 17      Miles     65  blue  74.461538
# 18     Hyeyun     80  blue  74.461538
# 19  Volodymyr     60  blue  74.461538
# 20      Yijia     88  blue  74.461538
# 21   Hsin-Yun     84  blue  74.461538
# 22      Wally     80  blue  74.461538

# %% [markdown]
# ### Creating new columns from custom functions

# %%
def is_top50(col):
    return col > col.median()

# %%
#roster['grade'] is a series
#roster[['grade']] is a dataframe
roster['top50'] = roster[['grade']].apply(is_top50)
roster
# Out:
#          name  grade group  group_avg  top50
# 0         Joe     77   red  79.500000   True
# 1     Frances     79   red  79.500000   True
# 2   Daniela V     75   red  79.500000  False
# 3   Daniela P    100   red  79.500000   True
# 4      Jarrod     86   red  79.500000   True
# 5        Jack     76   red  79.500000  False
# 6      Renata     81   red  79.500000   True
# 7         Max     68   red  79.500000  False
# 8      Joshua     69   red  79.500000  False
# 9       David     84   red  79.500000   True
# 10     Jihuan     82  blue  74.461538   True
# 11        Ali     72  blue  74.461538  False
# 12    Mostafa     75  blue  74.461538  False
# 13      Cesar     64  blue  74.461538  False
# 14     Austin     71  blue  74.461538  False
# 15        Ala     71  blue  74.461538  False
# 16     Sergii     76  blue  74.461538  False
# 17      Miles     65  blue  74.461538  False
# 18     Hyeyun     80  blue  74.461538   True
# 19  Volodymyr     60  blue  74.461538  False
# 20      Yijia     88  blue  74.461538   True
# 21   Hsin-Yun     84  blue  74.461538   True
# 22      Wally     80  blue  74.461538   True
